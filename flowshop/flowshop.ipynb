# %% [markdown]
# <a href="https://colab.research.google.com/github/Sakura-RaidenMEI/Funsearch_on_flowshop/blob/main/flowshop/flowshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Run FunSearch on Flowshop
# Five steps:
# 1. Implement 'LLM' interface.
# 2. Implement a 'SandBox' interface.
# 3. Prepare a 'specification'.
# 4. Prepare a dataset.
# 5. Start FunSearch.

# %% [markdown]
# ## Preparation: download the project file from github. And update system path.

# %%
# !git clone https://github.com/Sakura-RaidenMEI/Funsearch_on_flowshop.git

import sys

sys.path.append('/content/Funsearch_on_flowshop/')
# Out:
# fatal: destination path 'Funsearch_on_flowshop' already exists and is not an empty directory.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 1. Implement LLM interface

# %%
import time
import json
import multiprocessing
from typing import Collection, Any
import http.client
from implementation import sampler


def _trim_preface_of_body(sample: str) -> str:
    """Trim the redundant descriptions/symbols/'def' declaration before the function body.
    Please see my comments in sampler.LLM (in sampler.py).
    Since the LLM used in this file is not a pure code completion LLM, this trim function is required.

    -Example sample (function & description generated by LLM):
    -------------------------------------
    This is the optimized function ...
    def priority_v2(...) -> ...:
        return ...
    This function aims to ...
    -------------------------------------
    -This function removes the description above the function's signature, and the function's signature.
    -The indent of the code is preserved.
    -Return of this function:
    -------------------------------------
        return ...
    This function aims to ...
    -------------------------------------
    """
    lines = sample.splitlines()
    func_body_lineno = 0
    find_def_declaration = False
    for lineno, line in enumerate(lines):
        # find the first 'def' statement in the given code
        if line[:3] == 'def':
            func_body_lineno = lineno
            find_def_declaration = True
            break
    if find_def_declaration:
        code = ''
        for line in lines[func_body_lineno + 1:]:
            code += line + '\n'
        return code
    return sample


class LLMAPI(sampler.LLM):
    """Language model that predicts continuation of provided source code.
    """

    def __init__(self, samples_per_prompt: int, trim=True):
        super().__init__(samples_per_prompt)
        additional_prompt = ("Improve the scheduling heuristic to minimize makespan. "
                             "You can change how jobs are ordered or inserted. "
                             "Be creative. Think beyond NEH logic. "
                             "Pls only generate neh_heuristic(processing_times: np.ndarray) function"
                             "Use loops, conditionals, or clustering ideas. Only return valid Python code.")

        self._additional_prompt = additional_prompt
        self._trim = trim

    def draw_samples(self, prompt: str) -> Collection[str]:
        """Returns multiple predicted continuations of `prompt`."""
        return [self._draw_sample(prompt) for _ in range(self._samples_per_prompt)]

    def _draw_sample(self, content: str) -> str:
        prompt = '\n'.join([content, self._additional_prompt])
        message = [{'role': 'user', 'content': prompt}]

        while True:
            try:
                conn = http.client.HTTPSConnection("api.bltcy.ai")
                payload = json.dumps({
                    "max_tokens": 1024,
                    "model": "chatgpt-4o-latest",
                    "messages": [
                        {
                            "role": "user",
                            "content": prompt
                        }
                    ]
                })
                headers = {
                    'Authorization': 'Bearer sk-OmRJlpj2aI4A3GLvA4Bd841fCfB04b3e9eF6D0D9984f1719',
                    'User-Agent': 'Apifox/1.0.0 (https://apifox.com)',
                    'Content-Type': 'application/json'
                }
                conn.request("POST", "/v1/chat/completions", payload, headers)
                res = conn.getresponse()
                data = res.read().decode("utf-8")
                data = json.loads(data)
                response = data['choices'][0]['message']['content']
                if self._trim:
                    response = _trim_preface_of_body(response)
                return response
            except Exception:
                time.sleep(2)
                continue

# %% [markdown]
# ## 2. Implement a 'SandBox' interface

# %%
from implementation import evaluator
from implementation import evaluator_accelerate


class Sandbox(evaluator.Sandbox):
    """Sandbox for executing generated code. Implemented by RZ.

    RZ: Sandbox returns the 'score' of the program and:
    1) avoids the generated code to be harmful (accessing the internet, take up too much RAM).
    2) stops the execution of the code in time (avoid endless loop).
    """

    def __init__(self, verbose=False, numba_accelerate=True):
        """
        Args:
            verbose         : Print evaluate information.
            numba_accelerate: Use numba to accelerate the evaluation. It should be noted that not all numpy functions
                              support numba acceleration, such as np.piecewise().
        """
        self._verbose = verbose
        self._numba_accelerate = False

    def run(
            self,
            program: str,
            function_to_run: str,  # RZ: refers to the name of the function to run (e.g., 'evaluate')
            function_to_evolve: str,  # RZ: accelerate the code by decorating @numba.jit() on function_to_evolve.
            inputs: Any,  # refers to the dataset
            test_input: str,  # refers to the current instance
            timeout_seconds: int,
            **kwargs  # RZ: add this
    ) -> tuple[Any, bool]:
        """Returns `function_to_run(test_input)` and whether execution succeeded.

        RZ: If the generated code (generated by LLM) is executed successfully,
        the output of this function is the score of a given program.
        RZ: PLEASE NOTE THAT this SandBox is only designed for bin-packing problem.
        """
        dataset = {test_input: inputs[test_input]}
        try:
            result_queue = multiprocessing.Queue()
            process = multiprocessing.Process(
                target=self._compile_and_run_function,
                args=(program, function_to_run, function_to_evolve, dataset, self._numba_accelerate, result_queue)
            )
            process.start()
            process.join(timeout=timeout_seconds)
            if process.is_alive():
                # if the process is not finished in time, we consider the program illegal
                process.terminate()
                process.join()
                results = None, False
            else:
                if not result_queue.empty():
                    results = result_queue.get_nowait()
                else:
                    results = None, False

            return results
        except:
            return None, False

    def _compile_and_run_function(self, program, function_to_run, function_to_evolve, dataset, numba_accelerate,
                                  result_queue):
        try:
            # optimize the code (decorate function_to_run with @numba.jit())
            if numba_accelerate:
                program = evaluator_accelerate.add_numba_decorator(
                    program=program,
                    function_to_evolve=function_to_evolve
                )
            # compile the program, and maps the global func/var/class name to its address
            all_globals_namespace = {}
            # execute the program, map func/var/class to global namespace
            exec(program, all_globals_namespace)
            # get the pointer of 'function_to_run'
            function_to_run = all_globals_namespace[function_to_run]
            # return the execution results
            results = function_to_run(dataset)
            # the results must be int or float
            if not isinstance(results, (int, float)):
                result_queue.put((None, False))
                return
            result_queue.put((results, True))
        except Exception as e:
            import traceback
            error_msg = traceback.format_exc()
            print(f"[Sandbox Error] {error_msg}")  # 控制台
            # if raise any exception, we assume the execution failed
            result_queue.put((None, False))

# %% [markdown]
# ## 3. Prepare a 'specification'

# %%
specification = r'''
from typing import List
import numpy as np

import numpy as np


def compute_makespan(schedule: list[int], processing_times: np.ndarray) -> int:
    """
    Compute the makespan (total completion time) for a given job schedule in a PFSP.
    - schedule: list of job indices in the order they are processed.
    - processing_times: 2D numpy array of shape (num_jobs, num_machines) with processing times for each job on each machine.
    Returns the makespan (int) for the given order.
    """
    num_jobs = len(schedule)
    num_machines = processing_times.shape[1]
    if num_jobs == 0:
        return 0

    completion_times = np.zeros((num_jobs, num_machines), dtype=int)
    first_job = schedule[0]
    completion_times[0, 0] = processing_times[first_job, 0]
    for m in range(1, num_machines):
        completion_times[0, m] = completion_times[0, m-1] + processing_times[first_job, m]

    for i in range(1, num_jobs):
        job = schedule[i]
        completion_times[i, 0] = completion_times[i-1, 0] + processing_times[job, 0]
        for m in range(1, num_machines):
            completion_times[i, m] = max(completion_times[i, m-1], completion_times[i-1, m]) + processing_times[job, m]

    return int(completion_times[-1, -1])


@funsearch.run
def evaluate(instances: dict) -> float:
    """
    FunSearch evaluation function that computes the average makespan across multiple datasets.
    - instances: dict mapping instance names to 2D numpy arrays (processing time matrices).
    Returns the negative mean makespan (float) for optimization.
    """
    makespans = []
    for name in instances:
        processing_times = instances[name]
        if not isinstance(processing_times, np.ndarray):
            print(f"[ERROR] Instance {name} is not ndarray")
            continue
        if not np.issubdtype(processing_times.dtype, np.integer):
            processing_times = processing_times.astype(int)

        schedule = neh_heuristic(processing_times)
        ms = compute_makespan(schedule, processing_times)
        makespans.append(ms)

    if not makespans:
        return 1e9
    return -float(np.mean(makespans))


@funsearch.evolve
def neh_heuristic(processing_times: np.ndarray) -> list[int]:
    """
    An enhanced initial heuristic for the Permutation Flowshop Scheduling Problem (PFSP).

    This heuristic combines:
    - A weighted scoring for each job based on its total processing time and its maximum processing time.
      The weight parameter alpha balances these two criteria.
    - An iterative insertion procedure that builds an initial sequence.
    - A subsequent local search using pairwise swap improvements to further reduce the makespan.

    The resulting schedule (a list of job indices) is returned.
    """
    num_jobs, num_machines = processing_times.shape
    alpha = 0.7  # Weight parameter: can be tuned/evolved (alpha in [0, 1])

    # Compute a weighted score for each job.
    # Lower score indicates a job should be scheduled earlier.
    job_scores = []
    for job in range(num_jobs):
        total_time = processing_times[job].sum()
        max_time = processing_times[job].max()
        score = alpha * total_time + (1 - alpha) * max_time
        job_scores.append((job, score))

    # Sort jobs by ascending score (best candidate first)
    job_scores.sort(key=lambda x: x[1])

    # Build an initial sequence using iterative insertion
    sequence = [job_scores[0][0]]
    for job, _ in job_scores[1:]:
        best_sequence = None
        best_makespan = float('inf')
        # Try inserting the job in every possible position
        for pos in range(len(sequence) + 1):
            candidate_seq = sequence[:pos] + [job] + sequence[pos:]
            ms = compute_makespan(candidate_seq, processing_times)
            if ms < best_makespan:
                best_makespan = ms
                best_sequence = candidate_seq
        sequence = best_sequence

    # Local search: try pairwise swaps to further improve the sequence
    improvement = True
    while improvement:
        improvement = False
        current_makespan = compute_makespan(sequence, processing_times)
        for i in range(num_jobs - 1):
            for j in range(i + 1, num_jobs):
                new_seq = sequence.copy()
                new_seq[i], new_seq[j] = new_seq[j], new_seq[i]
                new_makespan = compute_makespan(new_seq, processing_times)
                if new_makespan < current_makespan:
                    sequence = new_seq
                    current_makespan = new_makespan
                    improvement = True
                    # Break out to restart the search after any improvement
                    break
            if improvement:
                break

    return sequence


'''

# %% [markdown]
# ## 4. Prepare a dataset

# %%
import os
import numpy as np
def load_datasets(dataset_folder):
    """
    Loads all datasets from the given folder, removing unnecessary job indices.

    :param dataset_folder: Path to the dataset folder.
    :return: Dictionary {dataset_name: job_matrix}
    """
    datasets = {}

    for root, _, files in os.walk(dataset_folder):
        for file in files:
            if file.endswith(".txt"):  # Ensure only .txt files are read
                file_path = os.path.join(root, file)

                with open(file_path, "r") as f:
                    first_line = f.readline().strip().split()
                    n_jobs, n_machines = int(first_line[0]), int(first_line[1])  # Read job/machine count

                    raw_data = np.loadtxt(f)
                    jobs = raw_data[:, 1::2]  # Keep only even-indexed columns (machine times)

                    if jobs.shape != (n_jobs, n_machines):
                        print(f" Warning: Mismatch in expected dimensions for {file_path}, skipping dataset.")
                        continue  # Skip invalid dataset

                    datasets[file] = jobs  # Store dataset by filename

    return datasets

# %% [markdown]
# ## 5. Start FunSearch
# Please note that in jupyter notebook the following code will fail. This is because juypter does not support multiprocessing. Colab backend supports multiprocessing.

# %%
from implementation import funsearch
from implementation import config

# It should be noted that the if __name__ == '__main__' is required.
# Because the inner code uses multiprocess evaluation.
if __name__ == '__main__':

    data_path = "/content/Funsearch_on_flowshop/data/"
    datasets = {}
    for subfolder in ["carlier", "heller", "reeves"]:
        datasets.update(load_datasets(os.path.join(data_path, subfolder)))

    print(f"Successfully loaded {len(datasets)} datasets.")

    instances = {
        "heller1.txt": datasets["heller1.txt"],
        "heller2.txt": datasets["heller2.txt"],
        "reeves1.txt": datasets["reeves1.txt"],
    }
    class_config = config.ClassConfig(llm_class=LLMAPI, sandbox_class=Sandbox)
    config = config.Config(samples_per_prompt=4, evaluate_timeout_seconds=30)
    global_max_sample_num = 50  # if it is set to None, funsearch will execute an endless loop
    funsearch.main(
        specification=specification,
        inputs=instances,
        config=config,
        max_sample_nums=global_max_sample_num,
        class_config=class_config,
        verbose=True,
        log_dir='../logs/evaluator.log/'
    )
# Out:
# Successfully loaded 31 datasets.
# INFO:absl:Best score of island 0 increased to -669.0
# INFO:absl:Best score of island 1 increased to -669.0
# INFO:absl:Best score of island 2 increased to -669.0
# INFO:absl:Best score of island 3 increased to -669.0
# INFO:absl:Best score of island 4 increased to -669.0
# INFO:absl:Best score of island 5 increased to -669.0
# INFO:absl:Best score of island 6 increased to -669.0
# INFO:absl:Best score of island 7 increased to -669.0
# INFO:absl:Best score of island 8 increased to -669.0
# INFO:absl:Best score of island 9 increased to -669.0
# ================= Evaluated Function =================
# def neh_heuristic(processing_times: np.ndarray) -> list[int]:
#     """
#     An enhanced initial heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This heuristic combines:
#     - A weighted scoring for each job based on its total processing time and its maximum processing time.
#       The weight parameter alpha balances these two criteria.
#     - An iterative insertion procedure that builds an initial sequence.
#     - A subsequent local search using pairwise swap improvements to further reduce the makespan.
#
#     The resulting schedule (a list of job indices) is returned.
#     """
#     num_jobs, num_machines = processing_times.shape
#     alpha = 0.7  # Weight parameter: can be tuned/evolved (alpha in [0, 1])
#
#     # Compute a weighted score for each job.
#     # Lower score indicates a job should be scheduled earlier.
#     job_scores = []
#     for job in range(num_jobs):
#         total_time = processing_times[job].sum()
#         max_time = processing_times[job].max()
#         score = alpha * total_time + (1 - alpha) * max_time
#         job_scores.append((job, score))
#
#     # Sort jobs by ascending score (best candidate first)
#     job_scores.sort(key=lambda x: x[1])
#
#     # Build an initial sequence using iterative insertion
#     sequence = [job_scores[0][0]]
#     for job, _ in job_scores[1:]:
#         best_sequence = None
#         best_makespan = float('inf')
#         # Try inserting the job in every possible position
#         for pos in range(len(sequence) + 1):
#             candidate_seq = sequence[:pos] + [job] + sequence[pos:]
#             ms = compute_makespan(candidate_seq, processing_times)
#             if ms < best_makespan:
#                 best_makespan = ms
#                 best_sequence = candidate_seq
#         sequence = best_sequence
#
#     # Local search: try pairwise swaps to further improve the sequence
#     improvement = True
#     while improvement:
#         improvement = False
#         current_makespan = compute_makespan(sequence, processing_times)
#         for i in range(num_jobs - 1):
#             for j in range(i + 1, num_jobs):
#                 new_seq = sequence.copy()
#                 new_seq[i], new_seq[j] = new_seq[j], new_seq[i]
#                 new_makespan = compute_makespan(new_seq, processing_times)
#                 if new_makespan < current_makespan:
#                     sequence = new_seq
#                     current_makespan = new_makespan
#                     improvement = True
#                     # Break out to restart the search after any improvement
#                     break
#             if improvement:
#                 break
#
#     return sequence
# ------------------------------------------------------
# Score        : -669.0
# Sample time  : None
# Evaluate time: 8.50501561164856
# Sample orders: None
# ======================================================
#
#
# [Generation 1] Current Best Score: -669.0
# Best Program Sample Order: None
# INFO:absl:Best score of island 4 increased to -668.3333333333334
# ================= Evaluated Function =================
# def neh_heuristic(processing_times: np.ndarray) -> list[int]:
#     """
#     An enhanced initial heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This heuristic combines:
#     - A weighted scoring for each job based on its total processing time and its maximum processing time.
#       The weight parameter alpha balances these two criteria.
#     - An iterative insertion procedure that builds an initial sequence.
#     - A subsequent local search using pairwise swap improvements to further reduce the makespan.
#
#     The resulting schedule (a list of job indices) is returned.
#     """
#     """
#     An improved initial heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This function enhances the original NEH heuristic by incorporating job clustering
#     and a more dynamic insertion strategy to minimize the makespan.
#     """
#     num_jobs, num_machines = processing_times.shape
#
#     # Compute total processing times for each job
#     total_processing_times = processing_times.sum(axis=1)
#
#     # Create a list of jobs sorted by total processing time
#     jobs = list(range(num_jobs))
#     jobs.sort(key=lambda job: total_processing_times[job])
#
#     # Initialize the sequence with the first job
#     sequence = [jobs[0]]
#
#     for job in jobs[1:]:
#         best_sequence = None
#         best_makespan = float('inf')
#
#         # Try inserting the job in every possible position
#         for pos in range(len(sequence) + 1):
#             candidate_seq = sequence[:pos] + [job] + sequence[pos:]
#             ms = compute_makespan(candidate_seq, processing_times)
#             if ms < best_makespan:
#                 best_makespan = ms
#                 best_sequence = candidate_seq
#
#         sequence = best_sequence
#
#     # Local search: try pairwise swaps to further improve the sequence
#     improvement = True
#     while improvement:
#         improvement = False
#         current_makespan = compute_makespan(sequence, processing_times)
#
#         # Use a more systematic approach to explore swaps
#         for i in range(num_jobs - 1):
#             for j in range(i + 1, num_jobs):
#                 new_seq = sequence.copy()
#                 new_seq[i], new_seq[j] = new_seq[j], new_seq[i]
#                 new_makespan = compute_makespan(new_seq, processing_times)
#
#                 if new_makespan < current_makespan:
#                     sequence = new_seq
#                     current_makespan = new_makespan
#                     improvement = True
#                     break
#             if improvement:
#                 break
#
#     return sequence
# ------------------------------------------------------
# Score        : -668.3333333333334
# Sample time  : 10.94875055551529
# Evaluate time: 7.43551230430603
# Sample orders: 2
# ======================================================
#
#
# [Generation 2] Current Best Score: -668.3333333333334
# Best Program Sample Order: 2
# INFO:absl:Best score of island 4 increased to -668.0
# ================= Evaluated Function =================
# def neh_heuristic(processing_times: np.ndarray) -> list[int]:
#     """
#     An enhanced initial heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This heuristic combines:
#     - A weighted scoring for each job based on its total processing time and its maximum processing time.
#       The weight parameter alpha balances these two criteria.
#     - An iterative insertion procedure that builds an initial sequence.
#     - A subsequent local search using pairwise swap improvements to further reduce the makespan.
#
#     The resulting schedule (a list of job indices) is returned.
#     """
#     """
#     An improved heuristic for the Permutation Flowshop Scheduling Problem (PFSP) that minimizes makespan.
#     This version incorporates job clustering based on processing times and a more dynamic insertion strategy.
#     """
#     num_jobs, num_machines = processing_times.shape
#
#     # Step 1: Compute total processing times and create clusters
#     total_times = processing_times.sum(axis=1)
#     job_indices = np.arange(num_jobs)
#
#     # Create clusters based on total processing times
#     clusters = {}
#     for idx in job_indices:
#         total_time = total_times[idx]
#         cluster_key = total_time // 10  # Group jobs into clusters of 10 units of total time
#         if cluster_key not in clusters:
#             clusters[cluster_key] = []
#         clusters[cluster_key].append(idx)
#
#     # Step 2: Sort clusters based on their average processing times
#     sorted_clusters = sorted(clusters.values(), key=lambda cluster: np.mean([total_times[job] for job in cluster]))
#
#     # Step 3: Build initial sequence from clusters
#     sequence = []
#     for cluster in sorted_clusters:
#         # Sort jobs within the cluster by their maximum processing time (to minimize bottlenecks)
#         cluster.sort(key=lambda job: processing_times[job].max())
#         sequence.extend(cluster)
#
#     # Step 4: Refine the sequence with a dynamic insertion strategy
#     refined_sequence = [sequence[0]]  # Start with the first job
#     for job in sequence[1:]:
#         best_sequence = None
#         best_makespan = float('inf')
#         for pos in range(len(refined_sequence) + 1):
#             candidate_seq = refined_sequence[:pos] + [job] + refined_sequence[pos:]
#             ms = compute_makespan(candidate_seq, processing_times)
#             if ms < best_makespan:
#                 best_makespan = ms
#                 best_sequence = candidate_seq
#         refined_sequence = best_sequence
#
#     # Step 5: Local search for further improvement
#     improvement = True
#     while improvement:
#         improvement = False
#         current_makespan = compute_makespan(refined_sequence, processing_times)
#         for i in range(num_jobs - 1):
#             for j in range(i + 1, num_jobs):
#                 new_seq = refined_sequence.copy()
#                 new_seq[i], new_seq[j] = new_seq[j], new_seq[i]
#                 new_makespan = compute_makespan(new_seq, processing_times)
#                 if new_makespan < current_makespan:
#                     refined_sequence = new_seq
#                     current_makespan = new_makespan
#                     improvement = True
#                     break
#             if improvement:
#                 break
#
#     return refined_sequence
# ------------------------------------------------------
# Score        : -668.0
# Sample time  : 10.94875055551529
# Evaluate time: 14.039658308029175
# Sample orders: 3
# ======================================================
#
#
# [Generation 3] Current Best Score: -668.0
# Best Program Sample Order: 3
# ================= Evaluated Function =================
# def neh_heuristic(processing_times: np.ndarray) -> list[int]:
#     """
#     An enhanced initial heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This heuristic combines:
#     - A weighted scoring for each job based on its total processing time and its maximum processing time.
#       The weight parameter alpha balances these two criteria.
#     - An iterative insertion procedure that builds an initial sequence.
#     - A subsequent local search using pairwise swap improvements to further reduce the makespan.
#
#     The resulting schedule (a list of job indices) is returned.
#     """
#     """
#     An improved heuristic for the Permutation Flowshop Scheduling Problem (PFSP)
#     that combines job clustering and a greedy insertion approach to minimize makespan.
#     """
#     num_jobs, num_machines = processing_times.shape
#
#     # Step 1: Cluster jobs based on their processing times
#     job_clusters = []
#     for job in range(num_jobs):
#         job_clusters.append((job, processing_times[job].sum()))
#
#     # Sort jobs based on total processing time (greedy clustering)
#     job_clusters.sort(key=lambda x: x[1])
#
#     # Step 2: Build an initial sequence using iterative insertion
#     sequence = []
#     for job, _ in job_clusters:
#         best_sequence = None
#         best_makespan = float('inf')
#
#         # Try inserting the job in every possible position
#         for pos in range(len(sequence) + 1):
#             candidate_seq = sequence[:pos] + [job] + sequence[pos:]
#             ms = compute_makespan(candidate_seq, processing_times)
#             if ms < best_makespan:
#                 best_makespan = ms
#                 best_sequence = candidate_seq
#
#         sequence = best_sequence
#
#     # Step 3: Local search with a focus on job pairs that can improve makespan
#     improvement = True
#     while improvement:
#         improvement = False
#         current_makespan = compute_makespan(sequence, processing_times)
#
#         for i in range(num_jobs - 1):
#             for j in range(i + 1, num_jobs):
#                 new_seq = sequence.copy()
#                 new_seq[i], new_seq[j] = new_seq[j], new_seq[i]
#                 new_makespan = compute_makespan(new_seq, processing_times)
#
#                 # Check if the swap leads to a better makespan
#                 if new_makespan < current_makespan:
#                     sequence = new_seq
#                     current_makespan = new_makespan
#                     improvement = True
#                     break
#             if improvement:
#                 break
#
#     return sequence
# ------------------------------------------------------
# Score        : -668.3333333333334
# Sample time  : 10.94875055551529
# Evaluate time: 8.940089702606201
# Sample orders: 4
# ======================================================
#
#
# [Generation 4] Current Best Score: -668.0
# Best Program Sample Order: 3
# ================= Evaluated Function =================
# def neh_heuristic(processing_times: np.ndarray) -> list[int]:
#     """
#     An enhanced initial heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This heuristic combines:
#     - A weighted scoring for each job based on its total processing time and its maximum processing time.
#       The weight parameter alpha balances these two criteria.
#     - An iterative insertion procedure that builds an initial sequence.
#     - A subsequent local search using pairwise swap improvements to further reduce the makespan.
#
#     The resulting schedule (a list of job indices) is returned.
#     """
#     """
#     An enhanced initial heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This version includes clustering of jobs based on their processing times to improve scheduling efficiency.
#     The resulting schedule (a list of job indices) is returned.
#     """
#     num_jobs, num_machines = processing_times.shape
#
#     # Step 1: Cluster jobs based on their processing times
#     job_clusters = {}
#     for job in range(num_jobs):
#         cluster_key = tuple(processing_times[job])  # Use processing times as the key for clustering
#         if cluster_key not in job_clusters:
#             job_clusters[cluster_key] = []
#         job_clusters[cluster_key].append(job)
#
#     # Step 2: Create a sorted job list based on total processing time
#     job_scores = []
#     for job in range(num_jobs):
#         total_time = processing_times[job].sum()
#         job_scores.append((job, total_time))
#
#     job_scores.sort(key=lambda x: x[1])  # Sort by total processing time
#
#     # Step 3: Build an initial sequence using iterative insertion
#     sequence = []
#     for job, _ in job_scores:
#         best_sequence = None
#         best_makespan = float('inf')
#         # Try inserting the job in every possible position
#         for pos in range(len(sequence) + 1):
#             candidate_seq = sequence[:pos] + [job] + sequence[pos:]
#             ms = compute_makespan(candidate_seq, processing_times)
#             if ms < best_makespan:
#                 best_makespan = ms
#                 best_sequence = candidate_seq
#         sequence = best_sequence
#
#     # Step 4: Local search to improve the sequence using pairwise swaps
#     improvement = True
#     while improvement:
#         improvement = False
#         current_makespan = compute_makespan(sequence, processing_times)
#         for i in range(num_jobs - 1):
#             for j in range(i + 1, num_jobs):
#                 new_seq = sequence.copy()
#                 new_seq[i], new_seq[j] = new_seq[j], new_seq[i]
#                 new_makespan = compute_makespan(new_seq, processing_times)
#                 if new_makespan < current_makespan:
#                     sequence = new_seq
#                     current_makespan = new_makespan
#                     improvement = True
#                     break
#             if improvement:
#                 break
#
#     return sequence
# ------------------------------------------------------
# Score        : -668.3333333333334
# Sample time  : 10.94875055551529
# Evaluate time: 8.018481254577637
# Sample orders: 5
# ======================================================
#
#
# [Generation 5] Current Best Score: -668.0
# Best Program Sample Order: 3
# ================= Evaluated Function =================
# def neh_heuristic(processing_times: np.ndarray) -> list[int]:
#     """
#     An enhanced initial heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This heuristic combines:
#     - A weighted scoring for each job based on its total processing time and its maximum processing time.
#       The weight parameter alpha balances these two criteria.
#     - An iterative insertion procedure that builds an initial sequence.
#     - A subsequent local search using pairwise swap improvements to further reduce the makespan.
#
#     The resulting schedule (a list of job indices) is returned.
#     """
#     """
#     An enhanced heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This heuristic includes:
#     - Job clustering based on processing times to create groups of similar jobs.
#     - A weighted scoring for each job based on its total processing time and its maximum processing time.
#     - An iterative insertion procedure for building the initial sequence.
#     - A local search using pairwise swap improvements to refine the sequence.
#
#     The resulting schedule (a list of job indices) is returned.
#     """
#     num_jobs, num_machines = processing_times.shape
#     alpha = 0.7  # Weight parameter: can be tuned/evolved (alpha in [0, 1])
#
#     # Step 1: Compute a weighted score for each job.
#     job_scores = []
#     for job in range(num_jobs):
#         total_time = processing_times[job].sum()
#         max_time = processing_times[job].max()
#         score = alpha * total_time + (1 - alpha) * max_time
#         job_scores.append((job, score))
#
#     # Step 2: Sort jobs by ascending score (best candidate first)
#     job_scores.sort(key=lambda x: x[1])
#
#     # Step 3: Create clusters based on processing times
#     clusters = []
#     cluster_size = max(1, num_jobs // 5)  # Create 5 clusters (or fewer if not enough jobs)
#
#     for i in range(0, num_jobs, cluster_size):
#         clusters.append(job_scores[i:i + cluster_size])
#
#     # Step 4: Build an initial sequence using iterative insertion from clusters
#     sequence = []
#
#     for cluster in clusters:
#         for job, _ in cluster:
#             best_sequence = None
#             best_makespan = float('inf')
#             # Try inserting the job in every possible position
#             for pos in range(len(sequence) + 1):
#                 candidate_seq = sequence[:pos] + [job] + sequence[pos:]
#                 ms = compute_makespan(candidate_seq, processing_times)
#                 if ms < best_makespan:
#                     best_makespan = ms
#                     best_sequence = candidate_seq
#             sequence = best_sequence
#
#     # Step 5: Local search: try pairwise swaps to further improve the sequence
#     improvement = True
#     while improvement:
#         improvement = False
#         current_makespan = compute_makespan(sequence, processing_times)
#         for i in range(num_jobs - 1):
#             for j in range(i + 1, num_jobs):
#                 new_seq = sequence.copy()
#                 new_seq[i], new_seq[j] = new_seq[j], new_seq[i]
#                 new_makespan = compute_makespan(new_seq, processing_times)
#                 if new_makespan < current_makespan:
#                     sequence = new_seq
#                     current_makespan = new_makespan
#                     improvement = True
#                     break
#             if improvement:
#                 break
#
#     return sequence
# ------------------------------------------------------
# Score        : -669.0
# Sample time  : 15.497928738594055
# Evaluate time: 8.698607444763184
# Sample orders: 6
# ======================================================
#
#
# [Generation 6] Current Best Score: -668.0
# Best Program Sample Order: 3
# ================= Evaluated Function =================
# def neh_heuristic(processing_times: np.ndarray) -> list[int]:
#     """
#     An enhanced initial heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This heuristic combines:
#     - A weighted scoring for each job based on its total processing time and its maximum processing time.
#       The weight parameter alpha balances these two criteria.
#     - An iterative insertion procedure that builds an initial sequence.
#     - A subsequent local search using pairwise swap improvements to further reduce the makespan.
#
#     The resulting schedule (a list of job indices) is returned.
#     """
#     """
#     An improved heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#     This version enhances job ordering and insertion strategies to minimize makespan
#     while maintaining a balance between total and maximum processing times.
#     """
#     num_jobs, num_machines = processing_times.shape
#     alpha = 0.5  # Weight parameter for balancing total and max processing times
#
#     # Compute a weighted score for each job
#     job_scores = []
#     for job in range(num_jobs):
#         total_time = processing_times[job].sum()
#         max_time = processing_times[job].max()
#         score = alpha * total_time + (1 - alpha) * max_time
#         job_scores.append((job, score))
#
#     # Sort jobs by ascending score
#     job_scores.sort(key=lambda x: x[1])
#
#     # Build an initial sequence using a modified insertion strategy
#     sequence = []
#     for job, _ in job_scores:
#         # Find the best position to insert the job using a greedy strategy
#         best_position = 0
#         best_makespan = float('inf')
#         for pos in range(len(sequence) + 1):
#             candidate_seq = sequence[:pos] + [job] + sequence[pos:]
#             ms = compute_makespan(candidate_seq, processing_times)
#             if ms < best_makespan:
#                 best_makespan = ms
#                 best_position = pos
#         # Insert the job at the best found position
#         sequence.insert(best_position, job)
#
#     # Local search: try pairwise swaps and also consider job clustering
#     improvement = True
#     while improvement:
#         improvement = False
#         current_makespan = compute_makespan(sequence, processing_times)
#         for i in range(num_jobs - 1):
#             for j in range(i + 1, num_jobs):
#                 new_seq = sequence.copy()
#                 new_seq[i], new_seq[j] = new_seq[j], new_seq[i]
#                 new_makespan = compute_makespan(new_seq, processing_times)
#                 if new_makespan < current_makespan:
#                     sequence = new_seq
#                     current_makespan = new_makespan
#                     improvement = True
#                     break
#             if improvement:
#                 break
#
#         # Additional clustering improvement
#         for cluster_size in range(2, num_jobs // 2 + 1):  # Check clusters of size 2 up to num_jobs // 2
#             for start in range(num_jobs - cluster_size + 1):
#                 cluster = sequence[start:start + cluster_size]
#                 for new_position in range(num_jobs - cluster_size + 1):
#                     if new_position != start:  # Avoid inserting at the same position
#                         new_seq = sequence[:start] + sequence[start + cluster_size:] + cluster
#                         ms = compute_makespan(new_seq, processing_times)
#                         if ms < current_makespan:
#                             sequence = new_seq
#                             current_makespan = ms
#                             improvement = True
#                             break
#                 if improvement:
#                     break
#
#     return sequence
# ------------------------------------------------------
# Score        : -733.0
# Sample time  : 15.497928738594055
# Evaluate time: 30.813379287719727
# Sample orders: 7
# ======================================================
#
#
# [Generation 7] Current Best Score: -668.0
# Best Program Sample Order: 3
# INFO:absl:Best score of island 1 increased to -665.0
# ================= Evaluated Function =================
# def neh_heuristic(processing_times: np.ndarray) -> list[int]:
#     """
#     An enhanced initial heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This heuristic combines:
#     - A weighted scoring for each job based on its total processing time and its maximum processing time.
#       The weight parameter alpha balances these two criteria.
#     - An iterative insertion procedure that builds an initial sequence.
#     - A subsequent local search using pairwise swap improvements to further reduce the makespan.
#
#     The resulting schedule (a list of job indices) is returned.
#     """
#     """
#     An enhanced initial heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This heuristic uses a clustering approach to group similar jobs and then applies an
#     iterative insertion procedure to build an initial sequence. It also includes a local
#     search using pairwise swap improvements to further reduce the makespan.
#
#     The resulting schedule (a list of job indices) is returned.
#     """
#     num_jobs, num_machines = processing_times.shape
#     alpha = 0.5  # Weight parameter for balancing criteria
#
#     # Compute a weighted score for each job.
#     job_scores = []
#     for job in range(num_jobs):
#         total_time = processing_times[job].sum()
#         max_time = processing_times[job].max()
#         score = alpha * total_time + (1 - alpha) * max_time
#         job_scores.append((job, score))
#
#     # Sort jobs by ascending score
#     job_scores.sort(key=lambda x: x[1])
#
#     # Cluster jobs based on processing time similarity
#     clusters = []
#     cluster_threshold = np.mean([score for _, score in job_scores])  # Average score as a threshold
#     current_cluster = []
#
#     for job, score in job_scores:
#         if not current_cluster or abs(score - current_cluster[0][1]) < cluster_threshold:
#             current_cluster.append((job, score))
#         else:
#             clusters.append(current_cluster)
#             current_cluster = [(job, score)]
#
#     if current_cluster:
#         clusters.append(current_cluster)
#
#     # Build an initial sequence using iterative insertion from clusters
#     sequence = []
#     for cluster in clusters:
#         cluster_jobs = [job for job, _ in cluster]
#         for job in cluster_jobs:
#             best_sequence = None
#             best_makespan = float('inf')
#             for pos in range(len(sequence) + 1):
#                 candidate_seq = sequence[:pos] + [job] + sequence[pos:]
#                 ms = compute_makespan(candidate_seq, processing_times)
#                 if ms < best_makespan:
#                     best_makespan = ms
#                     best_sequence = candidate_seq
#             sequence = best_sequence if best_sequence is not None else sequence
#
#     # Local search: try pairwise swaps to further improve the sequence
#     improvement = True
#     while improvement:
#         improvement = False
#         current_makespan = compute_makespan(sequence, processing_times)
#         for i in range(num_jobs - 1):
#             for j in range(i + 1, num_jobs):
#                 new_seq = sequence.copy()
#                 new_seq[i], new_seq[j] = new_seq[j], new_seq[i]
#                 new_makespan = compute_makespan(new_seq, processing_times)
#                 if new_makespan < current_makespan:
#                     sequence = new_seq
#                     current_makespan = new_makespan
#                     improvement = True
#                     break
#             if improvement:
#                 break
#
#     return sequence
# ------------------------------------------------------
# Score        : -665.0
# Sample time  : 15.497928738594055
# Evaluate time: 9.5745530128479
# Sample orders: 8
# ======================================================
#
#
# [Generation 8] Current Best Score: -665.0
# Best Program Sample Order: 8
# ================= Evaluated Function =================
# def neh_heuristic(processing_times: np.ndarray) -> list[int]:
#     """
#     An enhanced initial heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This heuristic combines:
#     - A weighted scoring for each job based on its total processing time and its maximum processing time.
#       The weight parameter alpha balances these two criteria.
#     - An iterative insertion procedure that builds an initial sequence.
#     - A subsequent local search using pairwise swap improvements to further reduce the makespan.
#
#     The resulting schedule (a list of job indices) is returned.
#     """
#     """
#     An enhanced NEH heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This version improves job ordering by clustering jobs based on their processing times
#     and using a more sophisticated insertion strategy to build the initial sequence.
#     """
#     num_jobs, num_machines = processing_times.shape
#     alpha = 0.7  # Weight parameter: can be tuned (alpha in [0, 1])
#
#     # Compute a weighted score for each job.
#     job_scores = []
#     for job in range(num_jobs):
#         total_time = processing_times[job].sum()
#         max_time = processing_times[job].max()
#         score = alpha * total_time + (1 - alpha) * max_time
#         job_scores.append((job, score))
#
#     # Sort jobs by ascending score
#     job_scores.sort(key=lambda x: x[1])
#
#     # Create clusters based on processing times
#     clusters = {}
#     for job, _ in job_scores:
#         cluster_key = tuple(processing_times[job])  # Use processing times as a key
#         if cluster_key not in clusters:
#             clusters[cluster_key] = []
#         clusters[cluster_key].append(job)
#
#     # Create a sorted list of clusters
#     sorted_clusters = sorted(clusters.items(), key=lambda x: sum(x[0]))
#
#     # Build an initial sequence using iterative insertion
#     sequence = []
#     for cluster in sorted_clusters:
#         for job in cluster[1]:  # Iterate through jobs in the cluster
#             best_sequence = None
#             best_makespan = float('inf')
#             # Try inserting the job in every possible position
#             for pos in range(len(sequence) + 1):
#                 candidate_seq = sequence[:pos] + [job] + sequence[pos:]
#                 ms = compute_makespan(candidate_seq, processing_times)
#                 if ms < best_makespan:
#                     best_makespan = ms
#                     best_sequence = candidate_seq
#             sequence = best_sequence
#
#     # Local search: try pairwise swaps to further improve the sequence
#     improvement = True
#     while improvement:
#         improvement = False
#         current_makespan = compute_makespan(sequence, processing_times)
#         for i in range(num_jobs - 1):
#             for j in range(i + 1, num_jobs):
#                 new_seq = sequence.copy()
#                 new_seq[i], new_seq[j] = new_seq[j], new_seq[i]
#                 new_makespan = compute_makespan(new_seq, processing_times)
#                 if new_makespan < current_makespan:
#                     sequence = new_seq
#                     current_makespan = new_makespan
#                     improvement = True
#                     break
#             if improvement:
#                 break
#
#     return sequence
# ------------------------------------------------------
# Score        : -669.0
# Sample time  : 15.497928738594055
# Evaluate time: 9.872061014175415
# Sample orders: 9
# ======================================================
#
#
# [Generation 9] Current Best Score: -665.0
# Best Program Sample Order: 8
# INFO:absl:Best score of island 5 increased to -665.0
# ================= Evaluated Function =================
# def neh_heuristic(processing_times: np.ndarray) -> list[int]:
#     """
#     An enhanced initial heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This heuristic combines:
#     - A weighted scoring for each job based on its total processing time and its maximum processing time.
#       The weight parameter alpha balances these two criteria.
#     - An iterative insertion procedure that builds an initial sequence.
#     - A subsequent local search using pairwise swap improvements to further reduce the makespan.
#
#     The resulting schedule (a list of job indices) is returned.
#     """
#     """
#     An improved heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This version uses clustering to group jobs with similar processing times,
#     and an optimized insertion strategy to build the initial sequence.
#     """
#     num_jobs, num_machines = processing_times.shape
#     alpha = 0.5  # Weight parameter for balancing criteria
#
#     # Compute a weighted score for each job
#     job_scores = []
#     for job in range(num_jobs):
#         total_time = processing_times[job].sum()
#         max_time = processing_times[job].max()
#         score = alpha * total_time + (1 - alpha) * max_time
#         job_scores.append((job, score))
#
#     # Sort jobs by ascending score
#     job_scores.sort(key=lambda x: x[1])
#
#     # Group jobs into clusters based on their scores
#     clusters = []
#     cluster_size = max(1, num_jobs // 5)  # Example: create 5 clusters
#     for i in range(0, num_jobs, cluster_size):
#         clusters.append([job for job, _ in job_scores[i:i + cluster_size]])
#
#     # Build an initial sequence using the clusters
#     sequence = []
#     for cluster in clusters:
#         for job in cluster:
#             best_sequence = None
#             best_makespan = float('inf')
#             # Try inserting the job in every possible position
#             for pos in range(len(sequence) + 1):
#                 candidate_seq = sequence[:pos] + [job] + sequence[pos:]
#                 ms = compute_makespan(candidate_seq, processing_times)
#                 if ms < best_makespan:
#                     best_makespan = ms
#                     best_sequence = candidate_seq
#             sequence = best_sequence
#
#     # Local search: try pairwise swaps to further improve the sequence
#     improvement = True
#     while improvement:
#         improvement = False
#         current_makespan = compute_makespan(sequence, processing_times)
#         for i in range(num_jobs - 1):
#             for j in range(i + 1, num_jobs):
#                 new_seq = sequence.copy()
#                 new_seq[i], new_seq[j] = new_seq[j], new_seq[i]
#                 new_makespan = compute_makespan(new_seq, processing_times)
#                 if new_makespan < current_makespan:
#                     sequence = new_seq
#                     current_makespan = new_makespan
#                     improvement = True
#                     # Break out to restart the search after any improvement
#                     break
#             if improvement:
#                 break
#
#     return sequence
# ------------------------------------------------------
# Score        : -665.0
# Sample time  : 11.756043910980225
# Evaluate time: 8.678715467453003
# Sample orders: 10
# ======================================================
#
#
# [Generation 10] Current Best Score: -665.0
# Best Program Sample Order: 8
# INFO:absl:Best score of island 5 increased to -664.6666666666666
# ================= Evaluated Function =================
# def neh_heuristic(processing_times: np.ndarray) -> list[int]:
#     """
#     An enhanced initial heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This heuristic combines:
#     - A weighted scoring for each job based on its total processing time and its maximum processing time.
#       The weight parameter alpha balances these two criteria.
#     - An iterative insertion procedure that builds an initial sequence.
#     - A subsequent local search using pairwise swap improvements to further reduce the makespan.
#
#     The resulting schedule (a list of job indices) is returned.
#     """
#     """
#     An improved heuristic for the Permutation Flowshop Scheduling Problem (PFSP)
#     that aims to minimize makespan through a combination of job ordering, insertion,
#     and clustering techniques.
#     """
#     num_jobs, num_machines = processing_times.shape
#     alpha = 0.5  # Weight parameter for balancing total and maximum processing times
#
#     # Compute a weighted score for each job
#     job_scores = []
#     for job in range(num_jobs):
#         total_time = processing_times[job].sum()
#         max_time = processing_times[job].max()
#         score = alpha * total_time + (1 - alpha) * max_time
#         job_scores.append((job, score))
#
#     # Sort jobs by ascending score
#     job_scores.sort(key=lambda x: x[1])
#
#     # Initialize the sequence with the first job
#     sequence = [job_scores[0][0]]
#
#     # Clustering approach: group jobs based on their processing times
#     clusters = {}
#     for job, _ in job_scores:
#         cluster_key = tuple(processing_times[job])  # Use processing times as a key
#         if cluster_key not in clusters:
#             clusters[cluster_key] = []
#         clusters[cluster_key].append(job)
#
#     # Insert jobs into the sequence based on clusters
#     for cluster in clusters.values():
#         for job in cluster:
#             best_sequence = None
#             best_makespan = float('inf')
#             # Try inserting the job in every possible position
#             for pos in range(len(sequence) + 1):
#                 candidate_seq = sequence[:pos] + [job] + sequence[pos:]
#                 ms = compute_makespan(candidate_seq, processing_times)
#                 if ms < best_makespan:
#                     best_makespan = ms
#                     best_sequence = candidate_seq
#             sequence = best_sequence
#
#     # Local search: try pairwise swaps to further improve the sequence
#     improvement = True
#     while improvement:
#         improvement = False
#         current_makespan = compute_makespan(sequence, processing_times)
#         for i in range(num_jobs - 1):
#             for j in range(i + 1, num_jobs):
#                 new_seq = sequence.copy()
#                 new_seq[i], new_seq[j] = new_seq[j], new_seq[i]
#                 new_makespan = compute_makespan(new_seq, processing_times)
#                 if new_makespan < current_makespan:
#                     sequence = new_seq
#                     current_makespan = new_makespan
#                     improvement = True
#                     break
#             if improvement:
#                 break
#
#     return sequence
# ------------------------------------------------------
# Score        : -664.6666666666666
# Sample time  : 11.756043910980225
# Evaluate time: 12.81553030014038
# Sample orders: 11
# ======================================================
#
#
# [Generation 11] Current Best Score: -664.6666666666666
# Best Program Sample Order: 11
# ================= Evaluated Function =================
# def neh_heuristic(processing_times: np.ndarray) -> list[int]:
#     """
#     An enhanced initial heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This heuristic combines:
#     - A weighted scoring for each job based on its total processing time and its maximum processing time.
#       The weight parameter alpha balances these two criteria.
#     - An iterative insertion procedure that builds an initial sequence.
#     - A subsequent local search using pairwise swap improvements to further reduce the makespan.
#
#     The resulting schedule (a list of job indices) is returned.
#     """
#     """
#     An improved heuristic for the Permutation Flowshop Scheduling Problem (PFSP)
#     that aims to minimize makespan by leveraging job clustering and a more
#     strategic insertion mechanism.
#
#     This heuristic uses:
#     - Job clustering based on processing times to group similar jobs.
#     - A greedy insertion strategy that considers both the current sequence and
#       the jobs' impact on the makespan.
#
#     The resulting schedule (a list of job indices) is returned.
#     """
#     num_jobs, num_machines = processing_times.shape
#
#     # Step 1: Cluster jobs based on their total processing time
#     job_indices = list(range(num_jobs))
#     job_total_times = processing_times.sum(axis=1)
#
#     # Sort jobs by total processing time
#     job_indices.sort(key=lambda x: job_total_times[x])
#
#     # Step 2: Build an initial sequence using a greedy approach
#     sequence = []
#
#     for job in job_indices:
#         best_position = 0
#         best_makespan = float('inf')
#
#         # Try to insert the job at every possible position
#         for pos in range(len(sequence) + 1):
#             candidate_seq = sequence[:pos] + [job] + sequence[pos:]
#             ms = compute_makespan(candidate_seq, processing_times)
#             if ms < best_makespan:
#                 best_makespan = ms
#                 best_position = pos
#
#         # Insert the job in the best found position
#         sequence.insert(best_position, job)
#
#     # Step 3: Local search: try pairwise swaps to improve the sequence
#     improvement = True
#     while improvement:
#         improvement = False
#         current_makespan = compute_makespan(sequence, processing_times)
#
#         for i in range(num_jobs - 1):
#             for j in range(i + 1, num_jobs):
#                 # Swap jobs i and j
#                 new_seq = sequence.copy()
#                 new_seq[i], new_seq[j] = new_seq[j], new_seq[i]
#                 new_makespan = compute_makespan(new_seq, processing_times)
#
#                 # If the new makespan is better, accept the new sequence
#                 if new_makespan < current_makespan:
#                     sequence = new_seq
#                     current_makespan = new_makespan
#                     improvement = True
#                     break
#             if improvement:
#                 break
#
#     return sequence
# ------------------------------------------------------
# Score        : -668.3333333333334
# Sample time  : 11.756043910980225
# Evaluate time: 11.730500936508179
# Sample orders: 12
# ======================================================
#
#
# [Generation 12] Current Best Score: -664.6666666666666
# Best Program Sample Order: 11
# ================= Evaluated Function =================
# def neh_heuristic(processing_times: np.ndarray) -> list[int]:
#     """
#     An enhanced initial heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This heuristic combines:
#     - A weighted scoring for each job based on its total processing time and its maximum processing time.
#       The weight parameter alpha balances these two criteria.
#     - An iterative insertion procedure that builds an initial sequence.
#     - A subsequent local search using pairwise swap improvements to further reduce the makespan.
#
#     The resulting schedule (a list of job indices) is returned.
#     """
#     """
#     An improved heuristic for the Permutation Flowshop Scheduling Problem (PFSP)
#     that focuses on minimizing makespan through a combination of job ordering,
#     clustering, and insertion strategies.
#
#     The resulting schedule (a list of job indices) is returned.
#     """
#     num_jobs, num_machines = processing_times.shape
#
#     # Calculate total processing times for each job
#     total_processing_times = processing_times.sum(axis=1)
#
#     # Create a list of jobs with their total processing times
#     jobs = list(range(num_jobs))
#
#     # Sort jobs based on total processing time (ascending)
#     jobs.sort(key=lambda job: total_processing_times[job])
#
#     # Build an initial sequence using clustering based on processing times
#     sequence = []
#
#     # Iteratively insert jobs into the sequence
#     for job in jobs:
#         best_sequence = None
#         best_makespan = float('inf')
#
#         # Try inserting the job in every possible position
#         for pos in range(len(sequence) + 1):
#             candidate_seq = sequence[:pos] + [job] + sequence[pos:]
#             ms = compute_makespan(candidate_seq, processing_times)
#             if ms < best_makespan:
#                 best_makespan = ms
#                 best_sequence = candidate_seq
#
#         sequence = best_sequence
#
#     # Local search: explore neighborhood solutions with a focus on job clustering
#     improvement = True
#     while improvement:
#         improvement = False
#         current_makespan = compute_makespan(sequence, processing_times)
#
#         # Check for two-opt style improvements
#         for i in range(num_jobs - 1):
#             for j in range(i + 1, num_jobs):
#                 new_seq = sequence.copy()
#                 new_seq[i], new_seq[j] = new_seq[j], new_seq[i]
#                 new_makespan = compute_makespan(new_seq, processing_times)
#
#                 if new_makespan < current_makespan:
#                     sequence = new_seq
#                     current_makespan = new_makespan
#                     improvement = True
#                     break
#             if improvement:
#                 break
#
#     return sequence
# ------------------------------------------------------
# Score        : -668.3333333333334
# Sample time  : 11.756043910980225
# Evaluate time: 7.620835781097412
# Sample orders: 13
# ======================================================
#
#
# [Generation 13] Current Best Score: -664.6666666666666
# Best Program Sample Order: 11
# ================= Evaluated Function =================
# def neh_heuristic(processing_times: np.ndarray) -> list[int]:
#     """
#     An enhanced initial heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This heuristic combines:
#     - A weighted scoring for each job based on its total processing time and its maximum processing time.
#       The weight parameter alpha balances these two criteria.
#     - An iterative insertion procedure that builds an initial sequence.
#     - A subsequent local search using pairwise swap improvements to further reduce the makespan.
#
#     The resulting schedule (a list of job indices) is returned.
#     """
#     """
#     An improved heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This heuristic enhances the NEH method by using clustering to group jobs based on their processing times
#     and applying a modified insertion strategy to build the initial sequence.
#     """
#     num_jobs, num_machines = processing_times.shape
#     alpha = 0.7  # Weight parameter for scoring
#
#     # Compute a weighted score for each job
#     job_scores = []
#     for job in range(num_jobs):
#         total_time = processing_times[job].sum()
#         max_time = processing_times[job].max()
#         score = alpha * total_time + (1 - alpha) * max_time
#         job_scores.append((job, score))
#
#     # Sort jobs by ascending score
#     job_scores.sort(key=lambda x: x[1])
#
#     # Clustering jobs based on their total processing times
#     clusters = {}
#     for job, _ in job_scores:
#         total_time = processing_times[job].sum()
#         cluster_key = total_time // 10  # Adjust the divisor for desired cluster granularity
#         if cluster_key not in clusters:
#             clusters[cluster_key] = []
#         clusters[cluster_key].append(job)
#
#     # Create an initial sequence using clustered jobs
#     sequence = []
#     for cluster in sorted(clusters.keys()):
#         for job in clusters[cluster]:
#             best_sequence = None
#             best_makespan = float('inf')
#             for pos in range(len(sequence) + 1):
#                 candidate_seq = sequence[:pos] + [job] + sequence[pos:]
#                 ms = compute_makespan(candidate_seq, processing_times)
#                 if ms < best_makespan:
#                     best_makespan = ms
#                     best_sequence = candidate_seq
#             sequence = best_sequence
#
#     # Local search: attempt to improve the sequence using pairwise swaps
#     improvement = True
#     while improvement:
#         improvement = False
#         current_makespan = compute_makespan(sequence, processing_times)
#         for i in range(num_jobs - 1):
#             for j in range(i + 1, num_jobs):
#                 new_seq = sequence.copy()
#                 new_seq[i], new_seq[j] = new_seq[j], new_seq[i]
#                 new_makespan = compute_makespan(new_seq, processing_times)
# ...
#         for pos in range(len(sequence) + 1):
#             candidate_seq = sequence[:pos] + [job] + sequence[pos:]
#             ms = compute_makespan(candidate_seq, processing_times)
#             if ms < best_makespan:
#                 best_makespan = ms
#                 best_sequence = candidate_seq
#
#         sequence = best_sequence
#
#     # Local search: try pairwise swaps to further improve the sequence
#     improvement = True
#     while improvement:
#         improvement = False
#         current_makespan = compute_makespan(sequence, processing_times)
#         for i in range(num_jobs - 1):
#             for j in range(i + 1, num_jobs):
#                 new_seq = sequence.copy()
#                 new_seq[i], new_seq[j] = new_seq[j], new_seq[i]
#                 new_makespan = compute_makespan(new_seq, processing_times)
#                 if new_makespan < current_makespan:
#                     sequence = new_seq
#                     current_makespan = new_makespan
#                     improvement = True
#                     break
#             if improvement:
#                 break
#
#     return sequence
# ------------------------------------------------------
# Score        : -644.3333333333334
# Sample time  : 13.004096984863281
# Evaluate time: 9.794691324234009
# Sample orders: 49
# ======================================================
#
#
# [Generation 49] Current Best Score: -643.6666666666666
# Best Program Sample Order: 24
# INFO:absl:Best score of island 6 increased to -668.3333333333334
# ================= Evaluated Function =================
# def neh_heuristic(processing_times: np.ndarray) -> list[int]:
#     """
#     An enhanced initial heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This heuristic combines:
#     - A weighted scoring for each job based on its total processing time and its maximum processing time.
#       The weight parameter alpha balances these two criteria.
#     - An iterative insertion procedure that builds an initial sequence.
#     - A subsequent local search using pairwise swap improvements to further reduce the makespan.
#
#     The resulting schedule (a list of job indices) is returned.
#     """
#     """
#     An improved heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This version incorporates a clustering approach to better order jobs before insertion,
#     which can lead to a more optimized schedule and reduced makespan.
#     """
#     num_jobs, num_machines = processing_times.shape
#
#     # Step 1: Compute job scores based on total processing time
#     job_scores = []
#     for job in range(num_jobs):
#         total_time = processing_times[job].sum()
#         job_scores.append((job, total_time))
#
#     # Step 2: Sort jobs by total processing time (ascending)
#     job_scores.sort(key=lambda x: x[1])
#
#     # Step 3: Cluster jobs based on processing times
#     clusters = []
#     cluster_size = max(1, num_jobs // 5)  # Create clusters, each with a size of 5 or less
#     for i in range(0, num_jobs, cluster_size):
#         cluster = job_scores[i:i + cluster_size]
#         clusters.append(cluster)
#
#     # Step 4: Create a sequence by inserting jobs from clusters
#     sequence = []
#     for cluster in clusters:
#         for job, _ in cluster:
#             best_sequence = None
#             best_makespan = float('inf')
#             # Try inserting the job in every possible position
#             for pos in range(len(sequence) + 1):
#                 candidate_seq = sequence[:pos] + [job] + sequence[pos:]
#                 ms = compute_makespan(candidate_seq, processing_times)
#                 if ms < best_makespan:
#                     best_makespan = ms
#                     best_sequence = candidate_seq
#             sequence = best_sequence
#
#     # Step 5: Local search: try pairwise swaps to further improve the sequence
#     improvement = True
#     while improvement:
#         improvement = False
#         current_makespan = compute_makespan(sequence, processing_times)
#         for i in range(num_jobs - 1):
#             for j in range(i + 1, num_jobs):
#                 new_seq = sequence.copy()
#                 new_seq[i], new_seq[j] = new_seq[j], new_seq[i]
#                 new_makespan = compute_makespan(new_seq, processing_times)
#                 if new_makespan < current_makespan:
#                     sequence = new_seq
#                     current_makespan = new_makespan
#                     improvement = True
#                     break
#             if improvement:
#                 break
#
#     return sequence
# ------------------------------------------------------
# Score        : -668.3333333333334
# Sample time  : 10.857085883617401
# Evaluate time: 8.041456937789917
# Sample orders: 50
# ======================================================
#
#
# [Generation 50] Current Best Score: -643.6666666666666
# Best Program Sample Order: 24
# [Sandbox Error] Traceback (most recent call last):
#   File "<ipython-input-6-3f27fa024b81>", line 79, in _compile_and_run_function
#     results = function_to_run(dataset)
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 50, in evaluate
#   File "<string>", line 119, in neh_heuristic
# IndexError: list index out of range
#
# [Sandbox Error] Traceback (most recent call last):
#   File "<ipython-input-6-3f27fa024b81>", line 79, in _compile_and_run_function
#     results = function_to_run(dataset)
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 50, in evaluate
#   File "<string>", line 119, in neh_heuristic
# IndexError: list index out of range
#
# [Sandbox Error] Traceback (most recent call last):
#   File "<ipython-input-6-3f27fa024b81>", line 79, in _compile_and_run_function
#     results = function_to_run(dataset)
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 50, in evaluate
#   File "<string>", line 119, in neh_heuristic
# IndexError: list index out of range
#
# ================= Evaluated Function =================
# def neh_heuristic(processing_times: np.ndarray) -> list[int]:
#     """
#     An enhanced initial heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This heuristic combines:
#     - A weighted scoring for each job based on its total processing time and its maximum processing time.
#       The weight parameter alpha balances these two criteria.
#     - An iterative insertion procedure that builds an initial sequence.
#     - A subsequent local search using pairwise swap improvements to further reduce the makespan.
#
#     The resulting schedule (a list of job indices) is returned.
#     """
#     """
#     An improved version of the NEH heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#     This version incorporates job clustering and a more sophisticated insertion strategy to minimize makespan.
#     """
#     num_jobs, num_machines = processing_times.shape
#     alpha = 0.5  # Weight parameter: can be tuned/evolved (alpha in [0, 1])
#
#     # Compute a weighted score for each job.
#     job_scores = []
#     for job in range(num_jobs):
#         total_time = processing_times[job].sum()
#         max_time = processing_times[job].max()
#         score = alpha * total_time + (1 - alpha) * max_time
#         job_scores.append((job, score))
#
#     # Sort jobs by ascending score
#     job_scores.sort(key=lambda x: x[1])
#
#     # Build an initial sequence using clustering
#     sequence = []
#     cluster_size = 3  # Size of clusters to create for better insertion
#     clusters = [job_scores[i:i + cluster_size] for i in range(0, num_jobs, cluster_size)]
#
#     for cluster in clusters:
#         cluster_jobs = [job for job, _ in cluster]
#         if not sequence:
#             sequence.extend(cluster_jobs)
#         else:
#             best_sequence = None
#             best_makespan = float('inf')
#             # Try inserting the cluster in every possible position
#             for pos in range(len(sequence) + 1):
#                 for job in cluster_jobs:
#                     candidate_seq = sequence[:pos] + [job] + sequence[pos:]
#                     ms = compute_makespan(candidate_seq, processing_times)
#                     if ms < best_makespan:
#                         best_makespan = ms
#                         best_sequence = candidate_seq
#             sequence = best_sequence
#
#     # Local search: try pairwise swaps to further improve the sequence
#     improvement = True
#     while improvement:
#         improvement = False
#         current_makespan = compute_makespan(sequence, processing_times)
#         for i in range(num_jobs - 1):
#             for j in range(i + 1, num_jobs):
#                 new_seq = sequence.copy()
#                 new_seq[i], new_seq[j] = new_seq[j], new_seq[i]
#                 new_makespan = compute_makespan(new_seq, processing_times)
#                 if new_makespan < current_makespan:
#                     sequence = new_seq
#                     current_makespan = new_makespan
#                     improvement = True
#                     break
#             if improvement:
#                 break
#
#     return sequence
# ------------------------------------------------------
# Score        : None
# Sample time  : 10.857085883617401
# Evaluate time: 0.567267656326294
# Sample orders: 51
# ======================================================
#
#
# [Generation 51] Current Best Score: -643.6666666666666
# Best Program Sample Order: 24
# ================= Evaluated Function =================
# def neh_heuristic(processing_times: np.ndarray) -> list[int]:
#     """
#     An enhanced initial heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This heuristic combines:
#     - A weighted scoring for each job based on its total processing time and its maximum processing time.
#       The weight parameter alpha balances these two criteria.
#     - An iterative insertion procedure that builds an initial sequence.
#     - A subsequent local search using pairwise swap improvements to further reduce the makespan.
#
#     The resulting schedule (a list of job indices) is returned.
#     """
#     """
#     An improved heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This version enhances the original NEH heuristic by introducing a clustering approach
#     for job ordering and a more sophisticated insertion method to minimize makespan.
#     """
#     num_jobs, num_machines = processing_times.shape
#
#     # Step 1: Compute total processing times for each job
#     total_processing_times = processing_times.sum(axis=1)
#
#     # Step 2: Cluster jobs based on their total processing time
#     # Here, we can use a simple clustering strategy by sorting jobs into groups
#     sorted_jobs = np.argsort(total_processing_times)
#
#     # Step 3: Build the initial sequence using an enhanced insertion method
#     sequence = []
#
#     for job in sorted_jobs:
#         best_sequence = None
#         best_makespan = float('inf')
#
#         # Try inserting the job in every possible position
#         for pos in range(len(sequence) + 1):
#             candidate_seq = sequence[:pos] + [job] + sequence[pos:]
#             ms = compute_makespan(candidate_seq, processing_times)
#             if ms < best_makespan:
#                 best_makespan = ms
#                 best_sequence = candidate_seq
#
#         sequence = best_sequence
#
#     # Step 4: Local search with a more refined swap strategy
#     improvement = True
#     while improvement:
#         improvement = False
#         current_makespan = compute_makespan(sequence, processing_times)
#
#         # Try a more selective pairwise swap approach
#         for i in range(num_jobs - 1):
#             for j in range(i + 1, num_jobs):
#                 new_seq = sequence.copy()
#                 new_seq[i], new_seq[j] = new_seq[j], new_seq[i]
#                 new_makespan = compute_makespan(new_seq, processing_times)
#
#                 # If the new makespan is better, accept the swap
#                 if new_makespan < current_makespan:
#                     sequence = new_seq
#                     current_makespan = new_makespan
#                     improvement = True
#                     break  # Break inner loop to restart search
#             if improvement:
#                 break
#
#     return sequence
# ------------------------------------------------------
# Score        : -669.3333333333334
# Sample time  : 10.857085883617401
# Evaluate time: 9.366052150726318
# Sample orders: 52
# ======================================================
#
#
# [Generation 52] Current Best Score: -643.6666666666666
# Best Program Sample Order: 24
# ================= Evaluated Function =================
# def neh_heuristic(processing_times: np.ndarray) -> list[int]:
#     """
#     An enhanced initial heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This heuristic combines:
#     - A weighted scoring for each job based on its total processing time and its maximum processing time.
#       The weight parameter alpha balances these two criteria.
#     - An iterative insertion procedure that builds an initial sequence.
#     - A subsequent local search using pairwise swap improvements to further reduce the makespan.
#
#     The resulting schedule (a list of job indices) is returned.
#     """
#     """
#     An improved heuristic for the Permutation Flowshop Scheduling Problem (PFSP).
#
#     This heuristic includes:
#     - Clustering of jobs based on their processing times to create a more balanced initial sequence.
#     - An iterative insertion procedure that builds the initial sequence.
#     - A local search using pairwise swap improvements to further reduce the makespan.
#
#     The resulting schedule (a list of job indices) is returned.
#     """
#     num_jobs, num_machines = processing_times.shape
#
#     # Step 1: Compute job scores based on processing times
#     job_scores = []
#     for job in range(num_jobs):
#         total_time = processing_times[job].sum()
#         score = total_time  # Using total processing time as the score
#         job_scores.append((job, score))
#
#     # Step 2: Sort jobs by their total processing time (ascending)
#     job_scores.sort(key=lambda x: x[1])
#
#     # Step 3: Clustering jobs into groups (e.g., pairs) for better insertion
#     clusters = []
#     cluster_size = 2  # Adjust this size based on experimentation
#     for i in range(0, num_jobs, cluster_size):
#         cluster = job_scores[i:i + cluster_size]
#         clusters.append(cluster)
#
#     # Step 4: Build an initial sequence using iterative insertion
#     sequence = []
#     for cluster in clusters:
#         for job, _ in cluster:
#             best_sequence = None
#             best_makespan = float('inf')
#             # Try inserting the job in every possible position
#             for pos in range(len(sequence) + 1):
#                 candidate_seq = sequence[:pos] + [job] + sequence[pos:]
#                 ms = compute_makespan(candidate_seq, processing_times)
#                 if ms < best_makespan:
#                     best_makespan = ms
#                     best_sequence = candidate_seq
#             sequence = best_sequence
#
#     # Step 5: Local search: try pairwise swaps to further improve the sequence
#     improvement = True
#     while improvement:
#         improvement = False
#         current_makespan = compute_makespan(sequence, processing_times)
#         for i in range(num_jobs - 1):
#             for j in range(i + 1, num_jobs):
#                 new_seq = sequence.copy()
#                 new_seq[i], new_seq[j] = new_seq[j], new_seq[i]
#                 new_makespan = compute_makespan(new_seq, processing_times)
#                 if new_makespan < current_makespan:
#                     sequence = new_seq
#                     current_makespan = new_makespan
#                     improvement = True
#                     # Break out to restart the search after any improvement
#                     break
#             if improvement:
#                 break
#
#     return sequence
# ------------------------------------------------------
# Score        : -668.3333333333334
# Sample time  : 10.857085883617401
# Evaluate time: 7.142683267593384
# Sample orders: 53
# ======================================================
#
#
# [Generation 53] Current Best Score: -643.6666666666666
# Best Program Sample Order: 24
